# %%
import pandas as pd

# %%
df = pd.read_csv('season_18_19.csv')
df2 = pd.read_csv('season_14_15.csv')

# %%
df[df['home'] =='AFC Bournemouth' ]
# Out:
#      Unnamed: 0 round match                          date   time  \
# 6             6    r1    m7     Saturday, 11. August 2018  15:00
# 26           26    r3    m7     Saturday, 25. August 2018  15:00
# 40           40    r5    m1  Saturday, 15. September 2018  15:00
# 64           64    r7    m5       Monday, 1. October 2018  20:00
# 80           80    r9    m1    Saturday, 20. October 2018  15:00
# 105         105   r11    m6    Saturday, 3. November 2018  12:30
# 123         123   r13    m4     Sunday, 25. November 2018  13:30
# 145         145   r15    m6     Tuesday, 4. December 2018  19:45
# 155         155   r16    m6    Saturday, 8. December 2018  12:30
# 176         176   r18    m7   Saturday, 22. December 2018  15:00
# 201         201   r21    m2    Wednesday, 2. January 2019  19:45
# 220         220   r23    m1    Saturday, 19. January 2019  15:00
# 238         238   r24    m9   Wednesday, 30. January 2019  19:45
# ...

# %%
df2[df2['home'] == 'Arsenal FC']['attendance'].apply(lambda x : x * 1000).mean()
# Out:
# 59991.73684210526

# %%
df[df['home'] == 'Arsenal FC']['attendance'].mean()
# Out:
# 59.89852631578948
